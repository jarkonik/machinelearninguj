# %% [markdown]
# # NLP Exercises
#
# We have five exercises in this section. The exercises are:
# 1. Build your own tokenizer, where you need to implement two functions to implement a tokenizer based on regular expression.
# 2. Get tags from Trump speech.
# 3. Get the nouns in the last 10 sentences from Trump's speech and find the nouns divided by sentencens. Use SpaCy.
# 4. Build your own Bag Of Words implementation using tokenizer created before.
# 5. Build a 5-gram model and clean up the results.

# %% [markdown]
# ## Exercise 1. Build your own tokenizer
#
# Build two different tokenizers:
# - ``tokenize_sentence``: function tokenizing text into sentences,
# - ``tokenize_word``: function tokenizing text into words.

# %%
from typing import List
import re

def tokenize_words(text: str) -> list:
    """Tokenize text into words using regex.

    Parameters
    ----------
    text: str
            Text to be tokenized

    Returns
    -------
    List[str]
            List containing words tokenized from text

    """
    return re.findall(r'\w+', text)

def tokenize_sentence(text: str) -> list:
    """Tokenize text into words using regex.

    Parameters
    ----------
    text: str
            Text to be tokenized

    Returns
    -------
    List[str]
            List containing words tokenized from text

    """
    return re.findall(r'\S.+?\.(?=\s(?![a-z])|[A-Z])', text)

text = "Here we go again. I was supposed to add this text later.\
Well, it's 10.p.m. here, and I'm actually having fun making this course. :o\
I hope you are getting along fine with this presentation, I really did try.\
And one last sentence, just so you can test you tokenizers better."

print("Tokenized sentences:")
print(tokenize_sentence(text))

print("Tokenized words:")
print(tokenize_words(text))
# Out:
# Tokenized sentences:
# ['Here we go again.', 'I was supposed to add this text later.', "Well, it's 10.p.m. here, and I'm actually having fun making this course.", ':oI hope you are getting along fine with this presentation, I really did try.']
# Tokenized words:
# ['Here', 'we', 'go', 'again', 'I', 'was', 'supposed', 'to', 'add', 'this', 'text', 'later', 'Well', 'it', 's', '10', 'p', 'm', 'here', 'and', 'I', 'm', 'actually', 'having', 'fun', 'making', 'this', 'course', 'oI', 'hope', 'you', 'are', 'getting', 'along', 'fine', 'with', 'this', 'presentation', 'I', 'really', 'did', 'try', 'And', 'one', 'last', 'sentence', 'just', 'so', 'you', 'can', 'test', 'you', 'tokenizers', 'better']

# %% [markdown]
# ## Exercise 2. Get tags from Trump speech using NLTK
#
# You should use the ``trump.txt`` file, read it and find the tags for each word. Use NLTK for it.

# %%
import nltk
from nltk import word_tokenize

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

file = open("./datasets/trump.txt", "r",encoding="utf-8") 
trump = file.read()
words = word_tokenize(trump)

nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\konik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\konik\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Thank', 'NNP'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('everybody', 'NN'),
#  ('.', '.'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('Thank', 'VB'),
#  ('you', 'PRP'),
#  ('very', 'RB'),
#  ('much', 'RB'),
#  ('.', '.'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('Matt', 'NNP'),
#  (',', ','),
#  ('for', 'IN'),
#  ('that', 'DT'),
#  ('great', 'JJ'),
#  ('introduction', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('thank', 'VB'),
#  ('you', 'PRP'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('big', 'JJ'),
#  ('crowd', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('incredible', 'JJ'),
#  ('.', '.'),
#  ('Really', 'RB'),
#  ('incredible', 'JJ'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('all', 'DT'),
#  ('come', 'VBP'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('way', 'NN'),
#  ('together', 'RB'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('come', 'VBN'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('way', 'NN'),
#  ('together', 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('thrilled', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('back', 'RB'),
#  ('at', 'IN'),
#  ('CPAC', 'NNP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('so', 'RB'),
#  ('many', 'JJ'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('wonderful', 'JJ'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('amazing', 'JJ'),
#  ('supporters', 'NNS'),
#  ('and', 'CC'),
#  ('proud', 'JJ'),
#  ('conservatives', 'NNS'),
#  ('.', '.'),
#  ('Remember', 'NNP'),
#  ('when', 'WRB'),
#  ('I', 'PRP'),
#  ('first', 'RB'),
#  ('started', 'VBD'),
#  ('running', 'VBG'),
#  ('?', '.'),
#  ('Because', 'IN'),
#  ('I', 'PRP'),
#  ('wasn', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('a', 'DT'),
#  ('politician', 'NN'),
#  (',', ','),
#  ('fortunately', 'RB'),
#  (',', ','),
#  ('but', 'CC'),
#  ('do', 'VBP'),
#  ('you', 'PRP'),
#  ('remember', 'VB'),
#  ('I', 'PRP'),
#  ('started', 'VBD'),
#  ('running', 'VBG'),
#  ('and', 'CC'),
#  ('people', 'NNS'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('you', 'PRP'),
#  ('sure', 'JJ'),
#  ('he', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'PDT'),
#  ('a', 'DT'),
#  ('conservative', 'JJ'),
#  ('?', '.'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('I', 'PRP'),
#  ('proved', 'VBD'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'PDT'),
#  ('a', 'DT'),
#  ('conservative', 'JJ'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('four', 'CD'),
#  ('decades', 'NNS'),
#  (',', ','),
#  ('this', 'DT'),
#  ('event', 'NN'),
#  ('has', 'VBZ'),
#  ('served', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('forum', 'NN'),
#  ('for', 'IN'),
#  ('our', 'PRP$'),
#  ('nation', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('top', 'JJ'),
#  ('leaders', 'NNS'),
#  (',', ','),
#  ('activists', 'NNS'),
#  (',', ','),
#  ('writers', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('thinkers', 'NNS'),
#  ('.', '.'),
#  ('Year', 'NN'),
#  ('after', 'IN'),
#  ('year', 'NN'),
#  (',', ','),
#  ('leaders', 'NNS'),
#  ('have', 'VBP'),
#  ('stood', 'VBN'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('stage', 'NN'),
#  ('to', 'TO'),
#  ('discuss', 'VB'),
#  ('what', 'WP'),
#  ('we', 'PRP'),
#  ('can', 'MD'),
#  ('do', 'VB'),
#  ('together', 'RB'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('our', 'PRP$'),
#  ('heritage', 'NN'),
#  (',', ','),
#  ('to', 'TO'),
#  ('promote', 'VB'),
#  ('our', 'PRP$'),
#  ('culture', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('defend', 'VB'),
#  ('our', 'PRP$'),
#  ('freedom', 'NN'),
#  ('.', '.'),
#  ('CPAC', 'NNP'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('been', 'VBN'),
#  ('about', 'RB'),
#  ('big', 'JJ'),
#  ('ideas', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('been', 'VBN'),
#  ('about', 'IN'),
#  ('putting', 'VBG'),
#  ('those', 'DT'),
#  ('ideas', 'NNS'),
#  ('into', 'IN'),
#  ('action', 'NN'),
#  ('—', 'NN'),
#  ('and', 'CC'),
#  ('CPAC', 'NNP'),
#  ('really', 'RB'),
#  ('has', 'VBZ'),
#  ('put', 'VBN'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('ideas', 'NNS'),
#  ('into', 'IN'),
#  ('action', 'NN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('’', 'VBP'),
#  ('ll', 'JJ'),
#  ('talk', 'NN'),
#  ('about', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('this', 'DT'),
#  ('morning', 'NN'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('with', 'IN'),
#  ('your', 'PRP$'),
#  ('help', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('put', 'VBN'),
#  ('more', 'JJR'),
#  ('great', 'JJ'),
#  ('conservative', 'JJ'),
#  ('ideas', 'NNS'),
#  ('into', 'IN'),
#  ('use', 'NN'),
#  ('than', 'IN'),
#  ('perhaps', 'RB'),
#  ('ever', 'RB'),
#  ('before', 'RB'),
#  ('in', 'IN'),
#  ('American', 'JJ'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('a', 'DT'),
#  ('nice', 'JJ'),
#  ('picture', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('.', '.'),
#  ('Look', 'VB'),
#  ('at', 'IN'),
#  ('that', 'DT'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('would', 'MD'),
#  ('love', 'VB'),
#  ('to', 'TO'),
#  ('watch', 'VB'),
#  ('that', 'IN'),
#  ('guy', 'NN'),
#  ('speak', 'NN'),
#  ('.', '.'),
#  ('Oh', 'UH'),
#  (',', ','),
#  ('boy', 'UH'),
#  ('.', '.'),
#  ('Oh', 'UH'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('try', 'VBP'),
#  ('like', 'IN'),
#  ('hell', 'NN'),
#  ('to', 'TO'),
#  ('hide', 'VB'),
#  ('that', 'IN'),
#  ('bald', 'NN'),
#  ('spot', 'NN'),
#  (',', ','),
#  ('folks', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('work', 'VBP'),
#  ('hard', 'RB'),
#  ('at', 'IN'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Doesn', 'NNP'),
#  ('’', 'NNP'),
#  ('t', 'VBD'),
#  ('look', 'NN'),
#  ('bad', 'JJ'),
#  ('.', '.'),
#  ('Hey', 'NNP'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('hanging', 'NN'),
#  ('in', 'IN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('hanging', 'NN'),
#  ('in', 'IN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('hanging', 'NN'),
#  ('in', 'IN'),
#  ('there', 'RB'),
#  (',', ','),
#  ('right', 'RB'),
#  ('?', '.'),
#  ('Together', 'RB'),
#  ('we', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('hanging', 'NN'),
#  ('in', 'IN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('confirmed', 'VBN'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('number', 'NN'),
#  (',', ','),
#  ('so', 'RB'),
#  ('important', 'JJ'),
#  (',', ','),
#  ('of', 'IN'),
#  ('circuit', 'NN'),
#  ('court', 'NN'),
#  ('judges', 'NNS'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('putting', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('more', 'JJR'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('they', 'PRP'),
#  ('will', 'MD'),
#  ('interpret', 'VB'),
#  ('the', 'DT'),
#  ('law', 'NN'),
#  ('as', 'IN'),
#  ('written', 'VBN'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('confirmed', 'VBN'),
#  ('an', 'DT'),
#  ('incredible', 'JJ'),
#  ('new', 'JJ'),
#  ('Supreme', 'NNP'),
#  ('Court', 'NNP'),
#  ('justice', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('man', 'NN'),
#  (',', ','),
#  ('Neil', 'NNP'),
#  ('Gorsuch', 'NNP'),
#  ('.', '.'),
#  ('Right', 'NNP'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('passed', 'VBN'),
#  ('massive', 'JJ'),
#  (',', ','),
#  ('biggest', 'JJS'),
#  ('in', 'IN'),
#  ('history', 'NN'),
#  (',', ','),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  ('and', 'CC'),
#  ('reforms', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('use', 'IN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  ('reform', 'NN'),
#  (',', ','),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('reform', 'NN'),
#  ('too', 'RB'),
#  (',', ','),
#  ('very', 'RB'),
#  ('positive', 'JJ'),
#  ('—', 'NN'),
#  ('I', 'PRP'),
#  ('don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('use', 'NN'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('when', 'WRB'),
#  ('we', 'PRP'),
#  ('were', 'VBD'),
#  ('first', 'RB'),
#  ('doing', 'VBG'),
#  ('it', 'PRP'),
#  ('I', 'PRP'),
#  ('told', 'VBD'),
#  ('everybody', 'NN'),
#  (',', ','),
#  ('everybody', 'NN'),
#  ('gathered', 'VBD'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('just', 'RB'),
#  ('talk', 'VB'),
#  ('about', 'IN'),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  ('.', '.'),
#  ('People', 'NNS'),
#  ('don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('know', 'VBP'),
#  ('what', 'WP'),
#  ('reform', 'NN'),
#  ('means', 'VBZ'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('think', 'VBP'),
#  ('reform', 'NN'),
#  ('might', 'MD'),
#  ('mean', 'VB'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('going', 'VBG'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('do', 'VBP'),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  ('.', '.'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('How', 'WRB'),
#  ('did', 'VBD'),
#  ('he', 'PRP'),
#  ('get', 'VB'),
#  ('in', 'IN'),
#  ('here', 'RB'),
#  (',', ','),
#  ('Matt', 'NNP'),
#  ('?', '.'),
#  ('Boy', 'NNP'),
#  ('.', '.'),
#  ('Okay', 'NNP'),
#  ('.', '.'),
#  ('Just', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('media', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('fake', 'JJ'),
#  ('news', 'NN'),
#  ('back', 'RB'),
#  ('there', 'RB'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('took', 'VBD'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('care', 'NN'),
#  ('of', 'IN'),
#  ('him', 'PRP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('were', 'VBD'),
#  ('very', 'RB'),
#  ('gentle', 'JJ'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('obnoxious', 'JJ'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('only', 'RB'),
#  ('one', 'CD'),
#  ('person', 'NN'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('thousands', 'NNS'),
#  ('of', 'IN'),
#  ('people', 'NNS'),
#  ('here', 'RB'),
#  ('.', '.'),
#  ('So', 'RB'),
#  (',', ','),
#  ('listen', 'UH'),
#  (',', ','),
#  ('tomorrow', 'NN'),
#  ('the', 'DT'),
#  ('headline', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('protesters', 'NNS'),
#  ('disturb', 'VB'),
#  ('the', 'DT'),
#  ('Trump', 'NNP'),
#  ('—', 'NNP'),
#  ('one', 'CD'),
#  ('person', 'NN'),
#  (',', ','),
#  ('folks', 'NNS'),
#  ('.', '.'),
#  ('Doesn', 'NNP'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('deserve', 'NN'),
#  ('a', 'DT'),
#  ('mention', 'NN'),
#  ('.', '.'),
#  ('Doesn', 'NNP'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('deserve', 'NN'),
#  ('a', 'DT'),
#  ('headline', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('headline', 'NN'),
#  ('tomorrow', 'NN'),
#  (',', ','),
#  ('disrupters', 'NNS'),
#  ('of', 'IN'),
#  ('CPAC', 'NNP'),
#  ('.', '.'),
#  ('One', 'CD'),
#  ('person', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('nice', 'JJ'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('looked', 'VBD'),
#  ('at', 'IN'),
#  ('him', 'PRP'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('immediately', 'RB'),
#  ('left', 'VBD'),
#  ('.', '.'),
#  ('Okay', 'NNP'),
#  ('.', '.'),
#  ('Now', 'RB'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('ve', 'RB'),
#  ('heard', 'VB'),
#  ('it', 'PRP'),
#  ('too', 'RB'),
#  ('often', 'RB'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('’', 'VBP'),
#  ('ll', 'NNS'),
#  ('have', 'VBP'),
#  ('one', 'CD'),
#  ('person', 'NN'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('hardly', 'RB'),
#  ('even', 'RB'),
#  ('hear', 'VBP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('biggest', 'JJS'),
#  ('disturbance', 'NN'),
#  ('are', 'VBP'),
#  ('you', 'PRP'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('know', 'VBP'),
#  ('why', 'WRB'),
#  ('?', '.'),
#  ('He', 'PRP'),
#  ('’', 'VBZ'),
#  ('ll', 'NNS'),
#  ('say', 'VBP'),
#  ('something', 'NN'),
#  (',', ','),
#  ('nobody', 'NN'),
#  ('hears', 'VBZ'),
#  ('him', 'PRP'),
#  (',', ','),
#  ('because', 'IN'),
#  ('—', 'NN'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('the', 'DT'),
#  ('crowd', 'NN'),
#  ('will', 'MD'),
#  ('start', 'VB'),
#  ('screaming', 'VBG'),
#  ('at', 'IN'),
#  ('him', 'PRP'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('sudden', 'JJ'),
#  ('we', 'PRP'),
#  ('start', 'VBP'),
#  ('—', 'JJ'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('okay', 'RP'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('show', 'VB'),
#  ('your', 'PRP$'),
#  ('spirit', 'NN'),
#  (',', ','),
#  ('right', 'RB'),
#  ('?', '.'),
#  ('You', 'PRP'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('show', 'VB'),
#  ('your', 'PRP$'),
#  ('spirit', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('true', 'JJ'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('we', 'PRP'),
#  ('passed', 'VBD'),
#  ('the', 'DT'),
#  ('biggest', 'JJS'),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('history', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('country', 'NN'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('called', 'VBN'),
#  ('tax', 'NN'),
#  ('cut', 'NN'),
#  ('and', 'CC'),
#  ('reform', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  ('to', 'TO'),
#  ('our', 'PRP$'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('don', 'JJ'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('use', 'NN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  ('reform', 'NN'),
#  ('.', '.'),
#  ('Because', 'IN'),
#  ('we', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('tax', 'NN'),
#  ('reform', 'NN'),
#  ('act', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  ('no', 'DT'),
#  ('wonder', 'NN'),
#  ('for', 'IN'),
#  ('45', 'CD'),
#  ('years', 'NNS'),
#  ('nothing', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('passed', 'VBN'),
#  ('.', '.'),
#  ('Because', 'IN'),
#  ('people', 'NNS'),
#  ('want', 'VBP'),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('they', 'PRP'),
#  ('don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('know', 'VBP'),
#  ('what', 'WP'),
#  ('reform', 'NN'),
#  ('means', 'VBZ'),
#  ('.', '.'),
#  ('Reform', 'NN'),
#  ('can', 'MD'),
#  ('mean', 'VB'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'VB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('pay', 'VB'),
#  ('more', 'JJR'),
#  ('tax', 'NN'),
#  ('.', '.'),
#  ('So', 'CC'),
#  ('I', 'PRP'),
#  ('convinced', 'VBP'),
#  ('politicians', 'NNS'),
#  ('who', 'WP'),
#  ('have', 'VBP'),
#  ('done', 'VBN'),
#  ('this', 'DT'),
#  ('all', 'DT'),
#  ('their', 'PRP$'),
#  ('lives', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('do', 'VBP'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('job', 'NN'),
#  ('in', 'IN'),
#  ('many', 'JJ'),
#  ('cases', 'NNS'),
#  (',', ','),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('—', 'PDT'),
#  ('the', 'DT'),
#  ('tax', 'NN'),
#  ('reform', 'NN'),
#  ('act', 'NN'),
#  ('of', 'IN'),
#  ('whatever', 'WDT'),
#  ('year', 'NN'),
#  ('we', 'PRP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('put', 'VB'),
#  (',', ','),
#  ('okay', 'NN'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('the', 'DT'),
#  ('tax', 'NN'),
#  ('reform', 'NN'),
#  ('act', 'NN'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('now', 'RB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('called', 'VBN'),
#  ('the', 'DT'),
#  ('tax', 'NN'),
#  ('act', 'NN'),
#  ('tax', 'NN'),
#  ('cut', 'NN'),
#  ('act', 'NN'),
#  ('and', 'CC'),
#  ('jobs', 'NNS'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('add', 'VB'),
#  ('jobs', 'NNS'),
#  ('into', 'IN'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('because', 'IN'),
#  ('we', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'NNS'),
#  ('picking', 'VBG'),
#  ('up', 'RP'),
#  ('a', 'DT'),
#  ('tremendous', 'JJ'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('jobs', 'NNS'),
#  ('.', '.'),
#  ('2.7', 'CD'),
#  ('million', 'CD'),
#  ('jobs', 'NNS'),
#  ('.', '.'),
#  ('2.7', 'CD'),
#  ('.', '.'),
#  ('So', 'RB'),
#  ('now', 'RB'),
#  ('people', 'NNS'),
#  ('hear', 'VBP'),
#  ('tax', 'NN'),
#  ('cuts', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('popular', 'JJ'),
#  ('.', '.'),
#  ('Remember', 'NNP'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('started', 'VBD'),
#  ('off', 'RP'),
#  ('a', 'DT'),
#  ('little', 'JJ'),
#  ('slow', 'JJ'),
#  ('.', '.'),
#  ('Then', 'RB'),
#  ('it', 'PRP'),
#  ('got', 'VBD'),
#  ('passed', 'VBN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('had', 'VBD'),
#  ('some', 'DT'),
#  ('great', 'JJ'),
#  ('help', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('say', 'VB'),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('some', 'DT'),
#  ('great', 'JJ'),
#  ('help', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Senate', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('House', 'NNP'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('guys', 'VBN'),
#  ('here', 'RB'),
#  ('today', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('Congressmen', 'NNP'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('senators', 'NNS'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('help', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('got', 'VBD'),
#  ('it', 'PRP'),
#  ('passed', 'VBD'),
#  (',', ','),
#  ('just', 'RB'),
#  ('—', 'VB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('easy', 'JJ'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('didn', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('have', 'VBP'),
#  ('one', 'CD'),
#  ('Democrat', 'NNP'),
#  ('vote', 'NN'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('that', 'IN'),
#  ('’', 'VBP'),
#  ('s', 'VB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('cost', 'VB'),
#  ('them', 'PRP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('midterms', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('know', 'VBP'),
#  ('that', 'IN'),
#  ('whoever', 'WP'),
#  ('wins', 'VBZ'),
#  ('the', 'DT'),
#  ('presidency', 'NN'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('disadvantage', 'NN'),
#  ('for', 'IN'),
#  ('whatever', 'WDT'),
#  ('reason', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('midterms', 'NNS'),
#  ('.', '.'),
#  ...]

# %% [markdown]
# ## Exercise 3. Get the nouns in the last 10 sentences from Trump's speech and find the nouns divided by sentencens. Use SpaCy.
#
# Please use Python list features to get the last 10 sentences and display nouns from it.

# %%
import spacy

file = open("./datasets/trump.txt", "r",encoding='utf-8') 
trump = file.read() 

### here comes your code

# %% [markdown]
# ## Exercise 4. Build your own Bag Of Words implementation using tokenizer created before
#
# You need to implement following methods:
#
# - ``fit_transform`` - gets a list of strings and returns matrix with it's BoW representation
# - ``get_features_names`` - returns list of words corresponding to columns in BoW

# %%
import numpy as np
import spacy
import en_core_web_sm

class BagOfWords:
    """Basic BoW implementation."""
    
    __nlp = en_core_web_sm
    __bow_list = []
    
    # your code goes maybe also here    
    def generate_vocabulary(corpus: list):
        for row in corpus:
            w_ tokenize_words(row)
            words.extend(w)
        
    words = sorted(list(set(words)))
    return words

    def fit_transform(self, corpus: list):
        """Transform list of strings into BoW array.

        Parameters
        ----------
        corpus: List[str]
                Corpus of texts to be transforrmed

        Returns
        -------
        np.array
                Matrix representation of BoW

        """
        # your code goes here    
        all_words = []
        for row in corpus:
            all_words.append(tokenize_words(row))
        print(all_words)
        return None
      

    def get_feature_names(self) -> list:
        """Return words corresponding to columns of matrix.

        Returns
        -------
        List[str]
                Words being transformed by fit function

        """   
        # your code goes here
        return None

corpus = [
     'Bag Of Words is based on counting',
     'words occurences throughout multiple documents.',
     'This is the third document.',
     'As you can see most of the words occur only once.',
     'This gives us a pretty sparse matrix, see below. Really, see below',
]    
    
vectorizer = BagOfWords()

X = vectorizer.fit_transform(corpus)
print(X)

vectorizer.get_feature_names()
len(vectorizer.get_feature_names())
# Out:
# [['Bag', 'Of', 'Words', 'is', 'based', 'on', 'counting'], ['words', 'occurences', 'throughout', 'multiple', 'documents'], ['This', 'is', 'the', 'third', 'document'], ['As', 'you', 'can', 'see', 'most', 'of', 'the', 'words', 'occur', 'only', 'once'], ['This', 'gives', 'us', 'a', 'pretty', 'sparse', 'matrix', 'see', 'below', 'Really', 'see', 'below']]
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-589c85f422fd> in <module>
#      59
#      60 vectorizer.get_feature_names()
# ---> 61 len(vectorizer.get_feature_names())
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ## Exercise 5. Build a 5-gram model and clean up the results.
#
# There are three tasks to do:
# 1. Use 5-gram model instead of 3.
# 2. Change to capital letter each first letter of a sentence.
# 3. Remove the whitespace between the last word in a sentence and . ! or ?.
#
# Hint: for 2. and 3. implement a function called ``clean_generated()`` that takes the generated text and fix both issues at once. It could be easier to fix the text after it's generated rather then doing some changes in the while loop.

# %%
from nltk.book import *

wall_street = text7.tokens

import re

tokens = wall_street

def cleanup():
    compiled_pattern = re.compile("^[a-zA-Z0-9.!?]")
    clean = list(filter(compiled_pattern.match,tokens))
    return clean
tokens = cleanup()

def build_ngrams():
    ngrams = []
    for i in range(len(tokens)-N+1):
        ngrams.append(tokens[i:i+N])
    return ngrams

def ngram_freqs(ngrams):
    counts = {}

    for ngram in ngrams:
        token_seq  = SEP.join(ngram[:-1])
        last_token = ngram[-1]

        if token_seq not in counts:
            counts[token_seq] = {}

        if last_token not in counts[token_seq]:
            counts[token_seq][last_token] = 0

        counts[token_seq][last_token] += 1;

    return counts

def next_word(text, N, counts):

    token_seq = SEP.join(text.split()[-(N-1):]);
    choices = counts[token_seq].items();

    total = sum(weight for choice, weight in choices)
    r = random.uniform(0, total)
    upto = 0
    for choice, weight in choices:
        upto += weight;
        if upto > r: return choice
    assert False # should not reach here

# %%
def clean_generated():
    # put your code here
    pass

N=3 # fix it for other value of N

SEP=" "

sentence_count=5

ngrams = build_ngrams()
start_seq="We have"

counts = ngram_freqs(ngrams)

if start_seq is None: start_seq = random.choice(list(counts.keys()))
generated = start_seq.lower();

sentences = 0
while sentences < sentence_count:
    generated += SEP + next_word(generated, N, counts)
    sentences += 1 if generated.endswith(('.','!', '?')) else 0

# put your code here:

print(generated)
